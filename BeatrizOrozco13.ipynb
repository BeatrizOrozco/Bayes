# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
import sklearn.linear_model

# %%
data = pd.read_csv('Cars93.csv')

# %%
len(data)
# Out:
# 93

# %%
len(data.keys())
# Out:
# 28

# %%
data.keys()
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
data[:10]
# Out:
#    Unnamed: 0 Manufacturer       Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura     Integra    Small       12.9   15.9       18.8
# 1           2        Acura      Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi          90  Compact       25.9   29.1       32.3
# 3           4         Audi         100  Midsize       30.8   37.7       44.6
# 4           5          BMW        535i  Midsize       23.7   30.0       36.2
# 5           6        Buick     Century  Midsize       14.2   15.7       17.3
# 6           7        Buick     LeSabre    Large       19.9   20.8       21.7
# 7           8        Buick  Roadmaster    Large       22.6   23.7       24.9
# 8           9        Buick     Riviera  Midsize       26.3   26.3       26.3
# 9          10     Cadillac     DeVille    Large       33.0   34.7       36.3
#
#    MPG.city  MPG.highway             AirBags        ...        Passengers  \
# ...

# %%
subset_data = data[['Price', 'Horsepower', 'MPG.highway', 'Turn.circle']]
#subset_data

# %%
from pandas.tools import plotting

_ = plotting.scatter_matrix(subset_data, figsize=(10,9))
# Out:
# C:\Users\Beatriz\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
linear = sklearn.linear_model.LinearRegression()

# %%
dir(linear)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_decision_function',
#  '_estimator_type',
#  '_get_param_names',
#  '_preprocess_data',
#  '_set_intercept',
#  'copy_X',
#  'fit',
#  'fit_intercept',
#  'get_params',
#  'n_jobs',
#  'normalize',
#  'predict',
#  'score',
#  'set_params']

# %%
X = data['Horsepower'].values.reshape(-1,1)
Y = data['Price'].values.reshape(-1,1)

# %%
linear.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(linear.intercept_)
# Out:
# [-1.39876912]

# %%
print(linear.coef_)
# Out:
# [[0.14537123]]

# %%
Y_predict = linear.predict(X)
plt.plot(X, Y_predict, label='modelo')
plt.scatter(X, Y, label='datos', color='red')
plt.legend()
plt.xlabel('Horsepower')
_ = plt.ylabel('Price')

# %%
print(linear.score(X, Y))
# Out:
# 0.6212869500338227

# %% [markdown]
# # Ejercicio 6.1
#
# Haga los ajustes, gráficas de modelo vs. datos y cálculo de score para los siguientes modelos:
#
# Price = $\beta_0$ + $\beta_1 \times $MPG.Highway.
#
# Price = $\beta_0$ + $\beta_1 \times $Turn.circle.
#
# De acuerdo al $R^2$ score, cual de los tres modelos es el mejor?

# %%
X = data['MPG.highway'].values.reshape(-1,1)
Y = data['Price'].values.reshape(-1,1)

# %%
linear.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_predict = linear.predict(X)
plt.plot(X, Y_predict, label='modelo')
plt.scatter(X, Y, label='datos', color='red')
plt.legend()
plt.xlabel('MPG.highway')
_ = plt.ylabel('Price')

# %%
print(linear.score(X, Y))
# Out:
# 0.3143624680022461

# %%
X = data['Turn.circle'].values.reshape(-1,1)
Y = data['Price'].values.reshape(-1,1)

# %%
linear.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_predict = linear.predict(X)
plt.plot(X, Y_predict, label='modelo')
plt.scatter(X, Y, label='datos', color='red')
plt.legend()
plt.xlabel('Turn.circle')
_ = plt.ylabel('Price')

# %%
print(linear.score(X, Y))
# Out:
# 0.15412685056314557

# %% [markdown]
# $R^2$ más grande es el de HorsePower, por lo que es el mejor modelo

# %% [markdown]
# # Ejercicio 6.2
#
# Haga los ajustes, gráficas de modelo vs. datos y cálculo de score para los tres modelos lineales que incluyan dos variables.
#
# De acuerdo al $R^2$ score, es alguno de estos modelos mejor que los tres anteriores?

# %%
subset_data = data[['Price', 'Horsepower', 'MPG.highway', 'Turn.circle']]

# %%
X_1 = data[['MPG.highway','Horsepower']]
linear.fit(X_1,Y)
Y_predict_1 = linear.predict(X_1)
Y = data['Price'].values.reshape(-1,1)

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.scatter(X_1['MPG.highway'], Y_predict_1, label='modelo')
plt.scatter(X_1['MPG.highway'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('MPG.highway')
_ = plt.ylabel('Price')

plt.subplot(122)
plt.scatter(X_1['Horsepower'], Y_predict_1, label='modelo')
plt.scatter(X_1['Horsepower'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('Horsepower')
_ = plt.ylabel('Price')

# %%
print(linear.score(X_1, Y))
# Out:
# 0.629865302134315

# %%
X_2 = data[['MPG.highway','Turn.circle']]
linear.fit(X_2,Y)
Y_predict_2 = linear.predict(X_2)
Y = data['Price'].values.reshape(-1,1)

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.scatter(X_2['MPG.highway'], Y_predict_2, label='modelo')
plt.scatter(X_2['MPG.highway'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('MPG.highway')
_ = plt.ylabel('Price')

plt.subplot(122)
plt.scatter(X_2['Turn.circle'], Y_predict_2, label='modelo')
plt.scatter(X_2['Turn.circle'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('Turn.circle')
_ = plt.ylabel('Price')

# %%
print(linear.score(X_2, Y))
# Out:
# 0.3198708229328999

# %%
X_3 = data[['Turn.circle','Horsepower']]
linear.fit(X_3,Y)
Y_predict_3 = linear.predict(X_3)
Y = data['Price'].values.reshape(-1,1)

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.scatter(X_3['Horsepower'], Y_predict_3, label='modelo')
plt.scatter(X_3['Horsepower'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('Horsepower')
_ = plt.ylabel('Price')

plt.subplot(122)
plt.scatter(X_3['Turn.circle'], Y_predict_3, label='modelo')
plt.scatter(X_3['Turn.circle'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('Turn.circle')
_ = plt.ylabel('Price')

# %%
print(linear.score(X_3, Y))
# Out:
# 0.6249029173886568

# %% [markdown]
# # Ejercicio 6.3
#
# Haga los ajustes, gráficas de modelo vs. datos y cálculo de score para el siguiente modelo:
#
# Price = $\beta_0$ + $\beta_1 \times $ Horsepower+ $\beta_2 \times $ MPG.Highway + $\beta_3 \times $ Turn.circle.
#
# De acuerdo al $R^2$ score, es este modelos mejor que los seis modelos anteriores?

# %%
X_4 = data[['Turn.circle','Horsepower','MPG.highway']]
linear.fit(X_4,Y)
Y_predict_4 = linear.predict(X_4)
Y = data['Price'].values.reshape(-1,1)

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.scatter(X_4['Horsepower'], Y_predict_4, label='modelo')
plt.scatter(X_4['Horsepower'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('Horsepower')
_ = plt.ylabel('Price')

plt.subplot(132)
plt.scatter(X_4['Turn.circle'], Y_predict_4, label='modelo')
plt.scatter(X_4['Turn.circle'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('Turn.circle')
_ = plt.ylabel('Price')

plt.subplot(133)
plt.scatter(X_4['MPG.highway'], Y_predict_4, label='modelo')
plt.scatter(X_4['MPG.highway'], Y, label='datos', color='red')
plt.legend()
plt.xlabel('MPG.highway')
_ = plt.ylabel('Price')

# %%
print(linear.score(X_4, Y))
# Out:
# 0.6404523210544848

# %% [markdown]
# # Ejercicio 6.4
#
# Calcule la evidencia bayesiana para los siete modelos lineales probados antes. ¿Cuál es el mejor modelo?

# %%
def model(x, c):
    n_dim = len(c)
    y = np.zeros(len(x))
    for i in range(n_dim):
        y += c[i] * x[i]
    return y
        
def loglike(x_obs, y_obs, y_sigma_obs, params):
    y_model = model(x_obs, params)
    d = -0.5 * ((y_model - y_obs)/y_sigma_obs)**2
    norm = np.sqrt(2.0 * np.pi * y_sigma_obs **2)
    return np.sum(d - np.log(norm))

def evidence(x_obs, y_obs, y_sigma_obs, n_dim=1, N = 10000):
    params = np.random.random(N * n_dim) * 2.0 - 1.0
    params = np.reshape(params, [N, n_dim])
    loglike_params = np.zeros(N)
    for i in range(N):
        loglike_params[i] = loglike(x_obs, y_obs, y_sigma_obs, params[i,:])
    
    e = np.exp(loglike_params)    
    return np.mean(e)

# %% [markdown]
# # Modelo 1

# %%
X = data['Horsepower'].values.reshape(-1,1)
Y = data['Price'].values.reshape(-1,1)
sigma_Y=np.std(Y)
n_dims = 2
e = np.zeros(n_dims)
for i in range(n_dims):
    e[i] = evidence(X, Y, sigma_Y, n_dim=i)
    print(e[i])
# Out:
# 0.0
# 0.0

# %%
X = data['MPG.highway'].values.reshape(-1,1)
Y = data['Price'].values.reshape(-1,1)
sigma_Y=np.std(Y)
n_dims = 2
e = np.zeros(n_dims)
for i in range(n_dims):
    e[i] = evidence(X, Y, sigma_Y, n_dim=i)
    print(e[i])
# Out:
# 0.0
# 0.0

# %%
X = data['Turn.circle'].values.reshape(-1,1)
Y = data['Price'].values.reshape(-1,1)
sigma_Y=np.std(Y)
n_dims = 2
e = np.zeros(n_dims)
for i in range(n_dims):
    e[i] = evidence(X, Y, sigma_Y, n_dim=i)
    print(e[i])
# Out:
# 0.0
# 0.0

# %% [markdown]
# # Modelo 4

# %%
def model(x, c):
    n_dim = len(c)
    y = np.zeros(len(x))
    for i in range(n_dim):
        y += c[i] * x[:,i]
    return y

# %%
X_1 = np.array(data[['MPG.highway','Horsepower']])
Y = np.array(data['Price'].values.reshape(-1,1))

# %%
n_dims = 3
e = np.zeros(n_dims)
for i in range(n_dims):
    e[i] = evidence(X_1, Y, sigma_Y, n_dim=i)
    print(e[i])
# Out:
# 0.0
# 0.0
# 0.0
